# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyaa-1702/nba_playoffs/blob/main/NBA_playoffs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Python libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics
import numpy as np

# %% [markdown]
# Reading data from csv file and extracting into Pandas dataframe

# %%
nba_dataset = pd.read_csv('/content/nba_playoffs.csv')

# %% [markdown]
# To count rows and columns in a dataframe

# %%
nba_dataset.shape
# Out:
# (25, 15)

# %%
nba_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   rank                   25 non-null     int64
#  1   player                 25 non-null     object
#  2   position               25 non-null     object
#  3   teams                  25 non-null     object
#  4   total_points           25 non-null     int64
#  5   total_games            25 non-null     int64
#  6   total_points_pre_game  25 non-null     float64
#  7   field_goals            25 non-null     int64
#  8   three_points_goals     25 non-null     int64
#  9   free_shots             25 non-null     int64
#  10  born                   25 non-null     object
#  11  active_player          25 non-null     int64
#  12  hall_of_fame           21 non-null     float64
#  13  country                25 non-null     object
# ...

# %% [markdown]
# To check missing values

# %%
nba_dataset.isnull().sum()
# Out:
# rank                     0
# player                   0
# position                 0
# teams                    0
# total_points             0
# total_games              0
# total_points_pre_game    0
# field_goals              0
# three_points_goals       0
# free_shots               0
# born                     0
# active_player            0
# hall_of_fame             4
# country                  0
# recording_year           0
# dtype: int64

# %%
nba_dataset.head()
# Out:
#    rank               player position  \
# 0     1         LeBron James    SF/PF
# 1     2       Michael Jordan    SG/SF
# 2     3  Kareem Abdul-Jabbar        C
# 3     4          Kobe Bryant    SG/SF
# 4     5     Shaquille O'Neal        C
#
#                                                teams  total_points  \
# 0  Cleveland Cavaliers (2006–2010, 2015–2018)\nMi...          8023
# 1               Chicago Bulls (1985–1993, 1995–1998)          5987
# 2  Milwaukee Bucks (1970–1974)\nLos Angeles Laker...          5762
# 3          Los Angeles Lakers (1997–2004, 2006–2012)          5640
# 4  Orlando Magic (1994–1996)\nLos Angeles Lakers ...          5250
#
#    total_games  total_points_pre_game  field_goals  three_points_goals  \
# 0          282                   28.5         2872                 460
# 1          179                   33.4         2188                 148
# 2          237                   24.3         2356                   0
# ...

# %%
X = nba_dataset.drop(['player','position','teams','born','country','total_games','hall_of_fame'],axis=1)
print (X)
# Out:
#     rank  total_points  total_points_pre_game  field_goals  \
# 0      1          8023                   28.5         2872
# 1      2          5987                   33.4         2188
# 2      3          5762                   24.3         2356
# 3      4          5640                   25.6         2014
# 4      5          5250                   24.3         2041
# 5      6          5172                   20.6         1975
# 6      7          4878                   29.4         1647
# 7      8          4761                   24.7         1743
# 8      9          4457                   29.1         1622
# 9     10          4045                   18.0         1613
# 10    11          3966                   27.0         1326
# 11    12          3954                   22.3         1450
# 12    13          3897                   23.8         1458
# 13    14          3776                   22.0         1451
# 14    15          3755                   25.9         1504
# ...

# %%
Y = nba_dataset['total_games']  # Target variable

# %% [markdown]
# Splitting Data into test and train set

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=2)

# %%
Correlation = X_train.corr()
Correlation.style.applymap(lambda x: 'background-color : blue' if x > 0.7 else '')
# Out:
# <ipython-input-57-e51bb63b056d>:2: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   Correlation.style.applymap(lambda x: 'background-color : blue' if x > 0.7 else '')
# <style type="text/css">
# #T_2be82_row0_col0, #T_2be82_row1_col1, #T_2be82_row1_col3, #T_2be82_row1_col5, #T_2be82_row2_col2, #T_2be82_row3_col1, #T_2be82_row3_col3, #T_2be82_row4_col4, #T_2be82_row4_col6, #T_2be82_row5_col1, #T_2be82_row5_col5, #T_2be82_row6_col4, #T_2be82_row6_col6 {
#   background-color: blue;
# }
# </style>
# <table id="T_2be82" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2be82_level0_col0" class="col_heading level0 col0" >rank</th>
#       <th id="T_2be82_level0_col1" class="col_heading level0 col1" >total_points</th>
#       <th id="T_2be82_level0_col2" class="col_heading level0 col2" >total_points_pre_game</th>
#       <th id="T_2be82_level0_col3" class="col_heading level0 col3" >field_goals</th>
# ...

# %% [markdown]
# # Correlation
#
# * field_goals, free_shots, three_points_goals have highest impact
# * Multi-Colinearity is Present

# %% [markdown]
# # Model training on Linear Regression

# %%
lin_reg_model = LinearRegression()
lin_reg_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predict on Test data and calculate score

# %%
from sklearn.metrics import r2_score
Y_pred = lin_reg_model.predict(X_test)
r2 = r2_score(Y_test, Y_pred)

print('R-Squared score for model Performance on Test : ', np.round(r2,2)*100)
# Out:
# R-Squared score for model Performance on Test :  99.0
